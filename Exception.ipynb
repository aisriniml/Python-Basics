# %% [markdown]
#  1. Syntax Errors
#
#   The errors which occurs because of invalid syntax are called syntax errors.
#
#  2. Runtime Errors
#
#   While executing the program if something goes wrong because of end user input or   programming logic or memory problems etc then we will get Runtime Errors.

# %%
# eg syntax
x=10 
if x==10
 print("Hello")
# Out:
#   File "<ipython-input-1-27289dfe9eee>", line 2
#     if x==10
#             ^
# SyntaxError: invalid syntax

# %%
print ("hell0o")
# Out:
# hell0o

# %%
# ex run time error

print(10/0)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-4-d7fb2557af48> in <module>()
#       1
# ----> 2 print(10/0)
#
# ZeroDivisionError: division by zero

# %%
x=int(input("enter number"))
print(x)
# Out:
# enter numberten
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-b0441751cb89> in <module>()
# ----> 1 x=int(input("enter number"))
#       2 print(x)
#
# ValueError: invalid literal for int() with base 10: 'ten'

# %% [markdown]
# ZeroDivisionError
#
# TypeError
#
# ValueError
#
# FileNotFoundError
#
# EOFError
#
# SleepingError
#
# TyrePuncturedError

# %% [markdown]
# try:
#
#   Risky Code
#
# except XXX:
#
#   Handling code/Alternative Code

# %%
print("statment 1")
print(20/0)
print("stmt 2")
# Out:
# statment 1
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-6-52fde1d9808f> in <module>()
#       1 print("statment 1")
# ----> 2 print(20/0)
#       3 print("stmt 2")
#
# ZeroDivisionError: division by zero

# %%
print("stat 1")

try:
  print(20/0)
except ZeroDivisionError:
  print("error")
finally:
  print("final")

print("stat 2")
# Out:
# stat 1
# error
# final
# stat 2

# %%
print("statment 1")

try:
  print(20/0)
except TypeError:
  print(20/2)
except TypeError:
  print(10/2)
finally: 
  print("final")

  
print("stmt 2")
# Out:
# statment 1
# final
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-16-c2ef135f2698> in <module>()
#       2
#       3 try:
# ----> 4   print(20/0)
#       5 except TypeError:
#       6   print(20/2)
#
# ZeroDivisionError: division by zero
