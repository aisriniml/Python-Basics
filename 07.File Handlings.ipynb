# %% [markdown]
# **f = open("abc.txt","w")**
#
# r - read onlymode
#
# w - write mode
#
# a - append mode
#
# r+ - read and write
#
# w+ - read and write
#
# a+ - read and append
#
# x - create and write

# %% [markdown]
# **name**  Name of opened file mode
#
# **Mode** in which the file is opened
#
# **closed** Returns boolean value indicates that file is closed or not
#
# readable() **bold text** Retruns boolean value indicates that whether file is readable or not
#
# **writable() **Returns boolean value indicates that whether file is writable or not.

# %%
f.close()

# %%
f=open("C:\\Users\\Bolle\\OneDrive\\Desktop\\test.txt",'w') 

print(f.name)

print(f.mode)

print(f.readable())

print(f.writable())

#f.close()

print(f.closed)
# Out:
# C:\Users\Bolle\OneDrive\Desktop\test.txt
# w
# False
# True
# False

# %% [markdown]
#  write(str)
#
#  writelines(list of lines)

# %%
f=open("C:\\Users\\Bolle\\OneDrive\\Desktop\\test.txt",'w') 
f.write('hello world')
f.write('Hi world')
f.close()

# %%
f=open("C:\\Users\\Bolle\\OneDrive\\Desktop\\test.txt",'r') 
lines=f.readlines()

for line in lines:
  print(line);
# Out:
# hello worldHi world

# %%
print(f.tell())
# Out:
# 19

# %%
f.seek(3)
f.tell()
# Out:
# 3

# %% [markdown]
# How to check a particular file exists or not?
#
# os.path.isfile(fname)

# %%
import os,sys


#dir(os)
dir(sys)
# Out:
# ['__displayhook__',
#  '__doc__',
#  '__excepthook__',
#  '__interactivehook__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '__stderr__',
#  '__stdin__',
#  '__stdout__',
#  '_clear_type_cache',
#  '_current_frames',
#  '_debugmallocstats',
#  '_getframe',
#  '_git',
#  '_home',
#  '_xoptions',
#  'abiflags',
#  'api_version',
#  'argv',
#  'base_exec_prefix',
#  'base_prefix',
#  'builtin_module_names',
#  'byteorder',
#  'call_tracing',
#  'callstats',
#  'copyright',
#  'displayhook',
#  'dont_write_bytecode',
#  'exc_info',
#  'excepthook',
#  'exec_prefix',
#  'executable',
#  'exit',
#  'flags',
#  'float_info',
#  'float_repr_style',
#  'get_asyncgen_hooks',
#  'get_coroutine_wrapper',
#  'getallocatedblocks',
#  'getcheckinterval',
#  'getdefaultencoding',
#  'getdlopenflags',
#  'getfilesystemencodeerrors',
#  'getfilesystemencoding',
#  'getprofile',
#  'getrecursionlimit',
#  'getrefcount',
#  'getsizeof',
#  'getswitchinterval',
#  'gettrace',
# ...

# %%
fname="C:\\Users\\Bolle\\OneDrive\\Desktop\\test123.txt"

os.path.isfile(fname)
# Out:
# False

# %% [markdown]
# **Handling Binary Data:**
#
# open("rossum.jpg","rb")
#
# open("rossum.jpg","wb")

# %%
f=open("rossum.jpg","rb")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-24-3241fb7c6f3e> in <module>()
# ----> 1 f=open("rossum.jpg","rb")
#
# FileNotFoundError: [Errno 2] No such file or directory: 'rossum.jpg'
