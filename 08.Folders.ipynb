# %% [markdown]
# # Working with Directories:
#
#  1. To know current working directory
#  2. To create a new directory
#  3. To remove an existing directory
#  4. To rename a directory
#  5. To list contents of the directory

# %%
import os

print(os.getcwd())
# Out:
# /content

# %%
os.mkdir("newfolders")

# %%
os.path.isdir("newfolders")
# Out:
# False

# %%
os.mkdir("newfolders2")

# %%
os.path.isdir("newfolders2")
# Out:
# False

# %%
os.removedirs("newfolders2")

# %%
os.rename("newfolders","pics")

# %%
os.path.isdir("newfolders")
# Out:
# False

# %%
os.listdir(".")
# Out:
# ['.config',
#  'test.txt',
#  'newfolder',
#  'pics',
#  'C:\\Users\\Bolle\\OneDrive\\Desktop\\test.txt',
#  'sample_data']
